# %%
# Import the dependencies.

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)

lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    
    
    # If the city is unique, then we will add it to the cities list.
    
    if city not in cities:
        
        cities.append(city)
        
        
# Print the city count to confirm sufficient count.

len(cities)
# Out:
# 785

# %%
# Import the time library and the datetime module from the datetime library 

import time

from datetime import datetime

# Import the requests library.

import requests

# Import the API key.

from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.

city_data = []

# Print the beginning of the logging.

print("Beginning Data Retrieval     ")
print("-----------------------------")


# Create counters.

record_count = 1

set_count = 1


# Loop through all the cities in our list.

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        
        record_count = 1
        
        
        
    # Create endpoint URL with each city.
    
    city_url = url + "&q=" + city.replace(" ","+")
    
    
    
    # Log the URL, record, and set numbers and the city.
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    
    # Add 1 to the record count.
    
    record_count += 1
    
    
    # Run an API request for each of the cities.

    try:
        
        # Parse the JSON and retrieve data.
        
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        
        city_lat = city_weather["coord"]["lat"]
        
        city_lng = city_weather["coord"]["lon"]
        
        city_max_temp = city_weather["main"]["temp_max"]
        
        city_humidity = city_weather["main"]["humidity"]
        
        city_clouds = city_weather["clouds"]["all"]
         
        city_wind = city_weather["wind"]["speed"]
        
        city_country = city_weather["sys"]["country"]
         
        city_weather_description = city_weather["weather"][0]["description"]
        
    
        
        # Append the city information into city_data list.
        
        city_data.append({"City": city.title(),
                          
                          "Lat": city_lat,
                          
                          "Lng": city_lng,
                          
                          "Max Temp": city_max_temp,
                          
                          "Humidity": city_humidity,
                          
                          "Cloudiness": city_clouds,
                          
                          "Wind Speed": city_wind,
                          
                          "Country": city_country,
                          
                          "Current Description": city_weather_description})

        
        
        
        
# If an error is experienced, skip the city.
    
    except:
        
        print("City not found. Skipping...")
        
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | berlevag
# Processing Record 3 of Set 1 | hualmay
# Processing Record 4 of Set 1 | richards bay
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | upernavik
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | katsuura
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | north bend
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | faya
# Processing Record 13 of Set 1 | tuktoyaktuk
# Processing Record 14 of Set 1 | matara
# Processing Record 15 of Set 1 | khalilabad
# Processing Record 16 of Set 1 | san patricio
# Processing Record 17 of Set 1 | castro
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | qaanaaq
# Processing Record 20 of Set 1 | ibra
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | aitape
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 27 of Set 1 | kahului
# Processing Record 28 of Set 1 | tual
# Processing Record 29 of Set 1 | coihaique
# Processing Record 30 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 1 | pathein
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | road town
# Processing Record 34 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 35 of Set 1 | norman wells
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | abeche
# Processing Record 38 of Set 1 | airai
# Processing Record 39 of Set 1 | san cristobal
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | lompoc
# Processing Record 42 of Set 1 | torbay
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | richmond
# Processing Record 46 of Set 1 | nemuro
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | tocopilla
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | odweyne
# Processing Record 1 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | macaboboni
# City not found. Skipping...
# Processing Record 4 of Set 2 | san juan
# Processing Record 5 of Set 2 | port elizabeth
# Processing Record 6 of Set 2 | pevek
# Processing Record 7 of Set 2 | ugoofaaru
# Processing Record 8 of Set 2 | avarua
# Processing Record 9 of Set 2 | puerto narino
# Processing Record 10 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 2 | tilichiki
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | mitsamiouli
# Processing Record 14 of Set 2 | tasiilaq
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | karaman
# Processing Record 17 of Set 2 | yumen
# Processing Record 18 of Set 2 | tuatapere
# Processing Record 19 of Set 2 | los llanos de aridane
# Processing Record 20 of Set 2 | bluff
# Processing Record 21 of Set 2 | kharan
# Processing Record 22 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 2 | bengkulu
# Processing Record 24 of Set 2 | normandin
# Processing Record 25 of Set 2 | lucapa
# Processing Record 26 of Set 2 | mutoko
# Processing Record 27 of Set 2 | tiksi
# Processing Record 28 of Set 2 | bredasdorp
# Processing Record 29 of Set 2 | guapi
# Processing Record 30 of Set 2 | poptun
# Processing Record 31 of Set 2 | saldanha
# Processing Record 32 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 2 | new norfolk
# Processing Record 34 of Set 2 | pochutla
# Processing Record 35 of Set 2 | manado
# Processing Record 36 of Set 2 | ilulissat
# Processing Record 37 of Set 2 | birao
# Processing Record 38 of Set 2 | komsomolskiy
# Processing Record 39 of Set 2 | albany
# Processing Record 40 of Set 2 | maxixe
# Processing Record 41 of Set 2 | samarai
# Processing Record 42 of Set 2 | vaini
# Processing Record 43 of Set 2 | acari
# Processing Record 44 of Set 2 | yellowknife
# Processing Record 45 of Set 2 | touros
# Processing Record 46 of Set 2 | lekoni
# Processing Record 47 of Set 2 | gornoye loo
# Processing Record 48 of Set 2 | ossora
# Processing Record 49 of Set 2 | port hardy
# Processing Record 50 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 3 | hasaki
# Processing Record 2 of Set 3 | gravdal
# Processing Record 3 of Set 3 | salalah
# Processing Record 4 of Set 3 | palauig
# Processing Record 5 of Set 3 | victoria
# Processing Record 6 of Set 3 | hilo
# Processing Record 7 of Set 3 | husavik
# Processing Record 8 of Set 3 | hirara
# Processing Record 9 of Set 3 | nacozari
# Processing Record 10 of Set 3 | alofi
# Processing Record 11 of Set 3 | kavieng
# Processing Record 12 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 13 of Set 3 | aykhal
# Processing Record 14 of Set 3 | khatanga
# Processing Record 15 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 3 | buenaventura
# Processing Record 17 of Set 3 | alugan
# Processing Record 18 of Set 3 | mokhsogollokh
# Processing Record 19 of Set 3 | yeppoon
# Processing Record 20 of Set 3 | cayenne
# Processing Record 21 of Set 3 | aklavik
# Processing Record 22 of Set 3 | chingirlau
# Processing Record 23 of Set 3 | la ronge
# Processing Record 24 of Set 3 | ribeira grande
# Processing Record 25 of Set 3 | longyearbyen
# Processing Record 26 of Set 3 | voi
# Processing Record 27 of Set 3 | eyl
# Processing Record 28 of Set 3 | thompson
# Processing Record 29 of Set 3 | saint-francois
# Processing Record 30 of Set 3 | humaita
# Processing Record 31 of Set 3 | borujerd
# Processing Record 32 of Set 3 | puerto ayora
# Processing Record 33 of Set 3 | seoul
# Processing Record 34 of Set 3 | banda aceh
# Processing Record 35 of Set 3 | georgetown
# Processing Record 36 of Set 3 | formosa
# Processing Record 37 of Set 3 | qujing
# Processing Record 38 of Set 3 | suluova
# Processing Record 39 of Set 3 | belaya gora
# Processing Record 40 of Set 3 | kodiak
# Processing Record 41 of Set 3 | lebu
# Processing Record 42 of Set 3 | ankazoabo
# Processing Record 43 of Set 3 | cidreira
# Processing Record 44 of Set 3 | rio verde de mato grosso
# Processing Record 45 of Set 3 | lorengau
# Processing Record 46 of Set 3 | balakhta
# Processing Record 47 of Set 3 | lavrentiya
# Processing Record 48 of Set 3 | saskylakh
# Processing Record 49 of Set 3 | nikel
# Processing Record 50 of Set 3 | prabumulih
# Processing Record 1 of Set 4 | saint-paul
# Processing Record 2 of Set 4 | mareeba
# Processing Record 3 of Set 4 | riyadh
# Processing Record 4 of Set 4 | north platte
# Processing Record 5 of Set 4 | lukovetskiy
# Processing Record 6 of Set 4 | mouzakion
# City not found. Skipping...
# Processing Record 7 of Set 4 | luganville
# Processing Record 8 of Set 4 | cherskiy
# Processing Record 9 of Set 4 | yar-sale
# Processing Record 10 of Set 4 | trapani
# Processing Record 11 of Set 4 | rocha
# Processing Record 12 of Set 4 | libenge
# Processing Record 13 of Set 4 | dalian
# Processing Record 14 of Set 4 | laguna
# Processing Record 15 of Set 4 | pangnirtung
# Processing Record 16 of Set 4 | nanortalik
# Processing Record 17 of Set 4 | mancio lima
# Processing Record 18 of Set 4 | dicabisagan
# Processing Record 19 of Set 4 | talnakh
# Processing Record 20 of Set 4 | teya
# Processing Record 21 of Set 4 | chuy
# Processing Record 22 of Set 4 | kutum
# Processing Record 23 of Set 4 | mecca
# Processing Record 24 of Set 4 | poum
# Processing Record 25 of Set 4 | antofagasta
# Processing Record 26 of Set 4 | mayo
# Processing Record 27 of Set 4 | iralaya
# Processing Record 28 of Set 4 | pisco
# Processing Record 29 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 4 | nampula
# Processing Record 31 of Set 4 | gualeguay
# Processing Record 32 of Set 4 | pavino
# Processing Record 33 of Set 4 | roma
# Processing Record 34 of Set 4 | carnarvon
# Processing Record 35 of Set 4 | hithadhoo
# Processing Record 36 of Set 4 | labuhan
# Processing Record 37 of Set 4 | blythe
# Processing Record 38 of Set 4 | ambatolampy
# Processing Record 39 of Set 4 | escanaba
# Processing Record 40 of Set 4 | wagar
# Processing Record 41 of Set 4 | boca do acre
# Processing Record 42 of Set 4 | pundaguitan
# Processing Record 43 of Set 4 | kaitangata
# Processing Record 44 of Set 4 | nadym
# Processing Record 45 of Set 4 | nikolskoye
# Processing Record 46 of Set 4 | ryotsu
# Processing Record 47 of Set 4 | toyooka
# Processing Record 48 of Set 4 | vagur
# Processing Record 49 of Set 4 | redmond
# Processing Record 50 of Set 4 | bay roberts
# Processing Record 1 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 5 | alim
# Processing Record 3 of Set 5 | muros
# Processing Record 4 of Set 5 | mansfield
# Processing Record 5 of Set 5 | pryozerne
# Processing Record 6 of Set 5 | pietermaritzburg
# Processing Record 7 of Set 5 | sibolga
# Processing Record 8 of Set 5 | saint-pierre
# Processing Record 9 of Set 5 | sainte-marie
# Processing Record 10 of Set 5 | bathsheba
# Processing Record 11 of Set 5 | cabo san lucas
# Processing Record 12 of Set 5 | vardo
# Processing Record 13 of Set 5 | moose factory
# Processing Record 14 of Set 5 | ostrovnoy
# Processing Record 15 of Set 5 | batsfjord
# Processing Record 16 of Set 5 | chernyshevskiy
# Processing Record 17 of Set 5 | leningradskiy
# Processing Record 18 of Set 5 | ostersund
# Processing Record 19 of Set 5 | nuzvid
# Processing Record 20 of Set 5 | severo-kurilsk
# Processing Record 21 of Set 5 | souillac
# Processing Record 22 of Set 5 | sarana
# Processing Record 23 of Set 5 | motril
# Processing Record 24 of Set 5 | candido mendes
# Processing Record 25 of Set 5 | san francisco
# Processing Record 26 of Set 5 | provideniya
# Processing Record 27 of Set 5 | zhigansk
# Processing Record 28 of Set 5 | mackay
# Processing Record 29 of Set 5 | hendrik-ido-ambacht
# Processing Record 30 of Set 5 | buritis
# Processing Record 31 of Set 5 | muswellbrook
# Processing Record 32 of Set 5 | saint-georges
# Processing Record 33 of Set 5 | arraial do cabo
# Processing Record 34 of Set 5 | uray
# Processing Record 35 of Set 5 | karczew
# Processing Record 36 of Set 5 | aswan
# Processing Record 37 of Set 5 | huanren
# Processing Record 38 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 5 | atar
# Processing Record 40 of Set 5 | chipinge
# Processing Record 41 of Set 5 | derzhavinsk
# Processing Record 42 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 5 | saint-leu
# Processing Record 44 of Set 5 | hovd
# Processing Record 45 of Set 5 | albanel
# Processing Record 46 of Set 5 | pueblo bello
# Processing Record 47 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 5 | neryungri
# Processing Record 49 of Set 5 | hirado
# Processing Record 50 of Set 5 | kyzyl-suu
# Processing Record 1 of Set 6 | benguela
# Processing Record 2 of Set 6 | tabuk
# Processing Record 3 of Set 6 | mbandaka
# Processing Record 4 of Set 6 | sovetskiy
# Processing Record 5 of Set 6 | salawagan
# Processing Record 6 of Set 6 | la palma
# Processing Record 7 of Set 6 | kirakira
# Processing Record 8 of Set 6 | ewa beach
# Processing Record 9 of Set 6 | berdigestyakh
# Processing Record 10 of Set 6 | kielce
# Processing Record 11 of Set 6 | tura
# Processing Record 12 of Set 6 | rayadrug
# Processing Record 13 of Set 6 | oktyabrskiy
# Processing Record 14 of Set 6 | acapulco
# Processing Record 15 of Set 6 | oussouye
# Processing Record 16 of Set 6 | codrington
# Processing Record 17 of Set 6 | mocuba
# Processing Record 18 of Set 6 | careiro da varzea
# Processing Record 19 of Set 6 | springbok
# Processing Record 20 of Set 6 | dunedin
# Processing Record 21 of Set 6 | chikhli
# Processing Record 22 of Set 6 | bethel
# Processing Record 23 of Set 6 | sheopur
# Processing Record 24 of Set 6 | vila velha
# Processing Record 25 of Set 6 | bambous virieux
# Processing Record 26 of Set 6 | cairns
# Processing Record 27 of Set 6 | iqaluit
# Processing Record 28 of Set 6 | linxia
# Processing Record 29 of Set 6 | cap-aux-meules
# Processing Record 30 of Set 6 | klaksvik
# Processing Record 31 of Set 6 | wewak
# Processing Record 32 of Set 6 | staryy nadym
# Processing Record 33 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 34 of Set 6 | hamilton
# Processing Record 35 of Set 6 | baiquan
# Processing Record 36 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 37 of Set 6 | byron bay
# Processing Record 38 of Set 6 | manhattan
# Processing Record 39 of Set 6 | juegang
# Processing Record 40 of Set 6 | truth or consequences
# Processing Record 41 of Set 6 | ruteng
# Processing Record 42 of Set 6 | boende
# Processing Record 43 of Set 6 | kommunisticheskiy
# Processing Record 44 of Set 6 | coquimbo
# Processing Record 45 of Set 6 | arshan
# Processing Record 46 of Set 6 | esperance
# Processing Record 47 of Set 6 | narsaq
# Processing Record 48 of Set 6 | hami
# Processing Record 49 of Set 6 | marolambo
# Processing Record 50 of Set 6 | saint george
# Processing Record 1 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 2 of Set 7 | vestmannaeyjar
# Processing Record 3 of Set 7 | vanavara
# Processing Record 4 of Set 7 | belmonte
# Processing Record 5 of Set 7 | namasuba
# Processing Record 6 of Set 7 | achhnera
# Processing Record 7 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 8 of Set 7 | kruisfontein
# Processing Record 9 of Set 7 | yarada
# Processing Record 10 of Set 7 | killybegs
# Processing Record 11 of Set 7 | bilibino
# Processing Record 12 of Set 7 | karratha
# Processing Record 13 of Set 7 | itarema
# Processing Record 14 of Set 7 | namibe
# Processing Record 15 of Set 7 | beyneu
# Processing Record 16 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 17 of Set 7 | platteville
# Processing Record 18 of Set 7 | egvekinot
# Processing Record 19 of Set 7 | skjervoy
# Processing Record 20 of Set 7 | voroshnevo
# Processing Record 21 of Set 7 | medea
# Processing Record 22 of Set 7 | akyab
# Processing Record 23 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 7 | severo-yeniseyskiy
# Processing Record 25 of Set 7 | tautira
# Processing Record 26 of Set 7 | gilazi
# City not found. Skipping...
# Processing Record 27 of Set 7 | masterton
# Processing Record 28 of Set 7 | naron
# Processing Record 29 of Set 7 | malakal
# Processing Record 30 of Set 7 | luba
# Processing Record 31 of Set 7 | ballina
# Processing Record 32 of Set 7 | terenga
# City not found. Skipping...
# Processing Record 33 of Set 7 | pingzhuang
# Processing Record 34 of Set 7 | cuiluan
# Processing Record 35 of Set 7 | ust-nera
# Processing Record 36 of Set 7 | deputatskiy
# Processing Record 37 of Set 7 | eureka
# Processing Record 38 of Set 7 | bubaque
# Processing Record 39 of Set 7 | kamenka
# Processing Record 40 of Set 7 | doha
# Processing Record 41 of Set 7 | flinders
# Processing Record 42 of Set 7 | zambezi
# Processing Record 43 of Set 7 | tabou
# Processing Record 44 of Set 7 | lagoa
# Processing Record 45 of Set 7 | trairi
# Processing Record 46 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 7 | sao joao da barra
# Processing Record 48 of Set 7 | tarbagatay
# Processing Record 49 of Set 7 | mbanza-ngungu
# Processing Record 50 of Set 7 | alta floresta
# Processing Record 1 of Set 8 | chiang khong
# Processing Record 2 of Set 8 | rawson
# Processing Record 3 of Set 8 | abu dhabi
# Processing Record 4 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 8 | mahebourg
# Processing Record 6 of Set 8 | cockburn town
# Processing Record 7 of Set 8 | ilhabela
# Processing Record 8 of Set 8 | gornozavodsk
# Processing Record 9 of Set 8 | guadalupe y calvo
# Processing Record 10 of Set 8 | havoysund
# Processing Record 11 of Set 8 | trimbak
# Processing Record 12 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 8 | ancud
# Processing Record 14 of Set 8 | honiara
# Processing Record 15 of Set 8 | marzuq
# Processing Record 16 of Set 8 | navirai
# Processing Record 17 of Set 8 | praia da vitoria
# Processing Record 18 of Set 8 | peterhead
# Processing Record 19 of Set 8 | zabol
# Processing Record 20 of Set 8 | havelock
# Processing Record 21 of Set 8 | katete
# Processing Record 22 of Set 8 | iskateley
# Processing Record 23 of Set 8 | chinsali
# Processing Record 24 of Set 8 | minab
# Processing Record 25 of Set 8 | kieta
# Processing Record 26 of Set 8 | magdagachi
# Processing Record 27 of Set 8 | borujan
# City not found. Skipping...
# Processing Record 28 of Set 8 | kidal
# Processing Record 29 of Set 8 | kushmurun
# Processing Record 30 of Set 8 | zhezkazgan
# Processing Record 31 of Set 8 | guerrero negro
# Processing Record 32 of Set 8 | esteli
# Processing Record 33 of Set 8 | oga
# Processing Record 34 of Set 8 | muzhi
# Processing Record 35 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 8 | xuddur
# Processing Record 37 of Set 8 | novaya ladoga
# Processing Record 38 of Set 8 | oranjemund
# Processing Record 39 of Set 8 | sitka
# Processing Record 40 of Set 8 | gisborne
# Processing Record 41 of Set 8 | amahai
# Processing Record 42 of Set 8 | ahipara
# Processing Record 43 of Set 8 | ginda
# Processing Record 44 of Set 8 | kaduna
# Processing Record 45 of Set 8 | nantucket
# Processing Record 46 of Set 8 | iquitos
# Processing Record 47 of Set 8 | honningsvag
# Processing Record 48 of Set 8 | krasnoselkup
# Processing Record 49 of Set 8 | ginir
# Processing Record 50 of Set 8 | gardan diwal
# City not found. Skipping...
# Processing Record 1 of Set 9 | nautla
# Processing Record 2 of Set 9 | umm lajj
# Processing Record 3 of Set 9 | rio branco
# Processing Record 4 of Set 9 | fairbanks
# Processing Record 5 of Set 9 | mount isa
# Processing Record 6 of Set 9 | benin
# Processing Record 7 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 9 | cotoca
# Processing Record 9 of Set 9 | pocone
# Processing Record 10 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 11 of Set 9 | toftir
# City not found. Skipping...
# Processing Record 12 of Set 9 | aller
# Processing Record 13 of Set 9 | brainerd
# Processing Record 14 of Set 9 | obregon
# Processing Record 15 of Set 9 | rio gallegos
# Processing Record 16 of Set 9 | miri
# Processing Record 17 of Set 9 | dubbo
# Processing Record 18 of Set 9 | puerto leguizamo
# Processing Record 19 of Set 9 | altamira
# Processing Record 20 of Set 9 | port blair
# Processing Record 21 of Set 9 | bandarbeyla
# Processing Record 22 of Set 9 | constitucion
# Processing Record 23 of Set 9 | port-gentil
# Processing Record 24 of Set 9 | ponta do sol
# Processing Record 25 of Set 9 | broken hill
# Processing Record 26 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 27 of Set 9 | lata
# Processing Record 28 of Set 9 | wajima
# Processing Record 29 of Set 9 | havre-saint-pierre
# Processing Record 30 of Set 9 | joshimath
# Processing Record 31 of Set 9 | wamba
# Processing Record 32 of Set 9 | faanui
# Processing Record 33 of Set 9 | marawi
# Processing Record 34 of Set 9 | qui nhon
# Processing Record 35 of Set 9 | piacabucu
# Processing Record 36 of Set 9 | lafiagi
# Processing Record 37 of Set 9 | sahuaripa
# Processing Record 38 of Set 9 | te anau
# Processing Record 39 of Set 9 | camalu
# Processing Record 40 of Set 9 | norwich
# Processing Record 41 of Set 9 | aripuana
# Processing Record 42 of Set 9 | jarocin
# Processing Record 43 of Set 9 | port lincoln
# Processing Record 44 of Set 9 | haikou
# Processing Record 45 of Set 9 | bouna
# Processing Record 46 of Set 9 | mahon
# Processing Record 47 of Set 9 | langsa
# Processing Record 48 of Set 9 | nara
# Processing Record 49 of Set 9 | masumbwe
# Processing Record 50 of Set 9 | lalibela
# Processing Record 1 of Set 10 | bafang
# Processing Record 2 of Set 10 | guangyuan
# Processing Record 3 of Set 10 | portland
# Processing Record 4 of Set 10 | oum hadjer
# Processing Record 5 of Set 10 | sungaipenuh
# Processing Record 6 of Set 10 | roald
# Processing Record 7 of Set 10 | cazaje
# City not found. Skipping...
# Processing Record 8 of Set 10 | salamiyah
# Processing Record 9 of Set 10 | ardistan
# City not found. Skipping...
# Processing Record 10 of Set 10 | ixtapa
# Processing Record 11 of Set 10 | hauge
# Processing Record 12 of Set 10 | tecoanapa
# Processing Record 13 of Set 10 | petrovskoye
# Processing Record 14 of Set 10 | log
# Processing Record 15 of Set 10 | areia branca
# Processing Record 16 of Set 10 | ketchikan
# Processing Record 17 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 18 of Set 10 | korla
# Processing Record 19 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 10 | una
# Processing Record 21 of Set 10 | fuerte olimpo
# Processing Record 22 of Set 10 | mayumba
# Processing Record 23 of Set 10 | salym
# Processing Record 24 of Set 10 | okato
# Processing Record 25 of Set 10 | nezhinka
# Processing Record 26 of Set 10 | gizo
# Processing Record 27 of Set 10 | leopoldshohe
# Processing Record 28 of Set 10 | venice
# Processing Record 29 of Set 10 | kampot
# Processing Record 30 of Set 10 | waitati
# Processing Record 31 of Set 10 | emerald
# Processing Record 32 of Set 10 | asau
# Processing Record 33 of Set 10 | nan
# Processing Record 34 of Set 10 | balikpapan
# Processing Record 35 of Set 10 | salina
# Processing Record 36 of Set 10 | biak
# Processing Record 37 of Set 10 | kosh-agach
# Processing Record 38 of Set 10 | mangrol
# Processing Record 39 of Set 10 | tateyama
# Processing Record 40 of Set 10 | sarh
# Processing Record 41 of Set 10 | sandwick
# Processing Record 42 of Set 10 | puerto baquerizo moreno
# Processing Record 43 of Set 10 | sorland
# Processing Record 44 of Set 10 | quixada
# Processing Record 45 of Set 10 | namie
# Processing Record 46 of Set 10 | rincon
# Processing Record 47 of Set 10 | henties bay
# Processing Record 48 of Set 10 | mason city
# Processing Record 49 of Set 10 | rundu
# Processing Record 50 of Set 10 | garissa
# Processing Record 1 of Set 11 | chicama
# Processing Record 2 of Set 11 | mesen
# Processing Record 3 of Set 11 | chern
# Processing Record 4 of Set 11 | maceio
# Processing Record 5 of Set 11 | verkhnevilyuysk
# Processing Record 6 of Set 11 | sioux lookout
# Processing Record 7 of Set 11 | puerto rico
# Processing Record 8 of Set 11 | koungou
# Processing Record 9 of Set 11 | uchana
# Processing Record 10 of Set 11 | cam ranh
# Processing Record 11 of Set 11 | sobolevo
# Processing Record 12 of Set 11 | la asuncion
# Processing Record 13 of Set 11 | edd
# Processing Record 14 of Set 11 | maine-soroa
# Processing Record 15 of Set 11 | camacha
# Processing Record 16 of Set 11 | jinchang
# Processing Record 17 of Set 11 | erenhot
# Processing Record 18 of Set 11 | garowe
# Processing Record 19 of Set 11 | hare bay
# Processing Record 20 of Set 11 | ouadda
# Processing Record 21 of Set 11 | araceli
# Processing Record 22 of Set 11 | yamada
# Processing Record 23 of Set 11 | xichang
# Processing Record 24 of Set 11 | tezu
# Processing Record 25 of Set 11 | godalming
# Processing Record 26 of Set 11 | ojinaga
# Processing Record 27 of Set 11 | cabra
# Processing Record 28 of Set 11 | vila franca do campo
# Processing Record 29 of Set 11 | oro valley
# Processing Record 30 of Set 11 | huainan
# Processing Record 31 of Set 11 | lanzhou
# Processing Record 32 of Set 11 | belyy yar
# Processing Record 33 of Set 11 | charters towers
# Processing Record 34 of Set 11 | nizhneudinsk
# Processing Record 35 of Set 11 | rolla
# Processing Record 36 of Set 11 | klyuchi
# Processing Record 37 of Set 11 | makinsk
# Processing Record 38 of Set 11 | turtas
# Processing Record 39 of Set 11 | nikita
# Processing Record 40 of Set 11 | kitaibaraki
# Processing Record 41 of Set 11 | nome
# Processing Record 42 of Set 11 | college
# Processing Record 43 of Set 11 | saint-joseph
# Processing Record 44 of Set 11 | verkhoyansk
# Processing Record 45 of Set 11 | isangel
# Processing Record 46 of Set 11 | eydhafushi
# Processing Record 47 of Set 11 | vao
# Processing Record 48 of Set 11 | san vicente
# Processing Record 49 of Set 11 | viedma
# Processing Record 50 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 1 of Set 12 | kavaratti
# Processing Record 2 of Set 12 | arvika
# Processing Record 3 of Set 12 | hun
# Processing Record 4 of Set 12 | hay river
# Processing Record 5 of Set 12 | at-bashi
# Processing Record 6 of Set 12 | fortuna
# Processing Record 7 of Set 12 | santa maria del oro
# Processing Record 8 of Set 12 | sechura
# Processing Record 9 of Set 12 | dingle
# Processing Record 10 of Set 12 | chelbasskaya
# Processing Record 11 of Set 12 | kasongo-lunda
# Processing Record 12 of Set 12 | raga
# Processing Record 13 of Set 12 | beringovskiy
# Processing Record 14 of Set 12 | olafsvik
# Processing Record 15 of Set 12 | mount gambier
# Processing Record 16 of Set 12 | sao filipe
# Processing Record 17 of Set 12 | oriximina
# Processing Record 18 of Set 12 | pierre
# Processing Record 19 of Set 12 | strelka
# Processing Record 20 of Set 12 | kemijarvi
# Processing Record 21 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 22 of Set 12 | okha
# Processing Record 23 of Set 12 | simav
# Processing Record 24 of Set 12 | barabai
# Processing Record 25 of Set 12 | aegviidu
# Processing Record 26 of Set 12 | axim
# Processing Record 27 of Set 12 | turukhansk
# Processing Record 28 of Set 12 | kalmunai
# Processing Record 29 of Set 12 | tianpeng
# Processing Record 30 of Set 12 | jiblah
# Processing Record 31 of Set 12 | emba
# Processing Record 32 of Set 12 | kargasok
# Processing Record 33 of Set 12 | burnie
# Processing Record 34 of Set 12 | the valley
# Processing Record 35 of Set 12 | geraldton
# Processing Record 36 of Set 12 | srednekolymsk
# Processing Record 37 of Set 12 | rab
# City not found. Skipping...
# Processing Record 38 of Set 12 | nelson bay
# Processing Record 39 of Set 12 | kamen-na-obi
# Processing Record 40 of Set 12 | maningrida
# Processing Record 41 of Set 12 | lagos
# Processing Record 42 of Set 12 | mancora
# Processing Record 43 of Set 12 | columbus
# Processing Record 44 of Set 12 | nouadhibou
# Processing Record 45 of Set 12 | charlestown
# Processing Record 46 of Set 12 | vitoria da conquista
# Processing Record 47 of Set 12 | la cruz
# Processing Record 48 of Set 12 | caxito
# Processing Record 49 of Set 12 | luderitz
# Processing Record 50 of Set 12 | bowen
# Processing Record 1 of Set 13 | zhitikara
# City not found. Skipping...
# Processing Record 2 of Set 13 | skagen
# Processing Record 3 of Set 13 | alihe
# Processing Record 4 of Set 13 | venado tuerto
# Processing Record 5 of Set 13 | peniche
# Processing Record 6 of Set 13 | kununurra
# Processing Record 7 of Set 13 | poso
# Processing Record 8 of Set 13 | chik
# Processing Record 9 of Set 13 | buchanan
# Processing Record 10 of Set 13 | salinopolis
# Processing Record 11 of Set 13 | yining
# Processing Record 12 of Set 13 | opuwo
# Processing Record 13 of Set 13 | gobo
# Processing Record 14 of Set 13 | huayang
# Processing Record 15 of Set 13 | clyde river
# Processing Record 16 of Set 13 | westport
# Processing Record 17 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 18 of Set 13 | shingu
# Processing Record 19 of Set 13 | jiangkou
# Processing Record 20 of Set 13 | ekhabi
# Processing Record 21 of Set 13 | selma
# Processing Record 22 of Set 13 | chepareria
# Processing Record 23 of Set 13 | veraval
# Processing Record 24 of Set 13 | nuuk
# Processing Record 25 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 26 of Set 13 | baruun-urt
# Processing Record 27 of Set 13 | maragogi
# Processing Record 28 of Set 13 | belousovka
# Processing Record 29 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 31 of Set 13 | kitimat
# Processing Record 32 of Set 13 | gejiu
# Processing Record 33 of Set 13 | ferkessedougou
# Processing Record 34 of Set 13 | maicao
# Processing Record 35 of Set 13 | pipri
# Processing Record 36 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 13 | qidong
# Processing Record 38 of Set 13 | coahuayana
# Processing Record 39 of Set 13 | tiruvottiyur
# City not found. Skipping...
# Processing Record 40 of Set 13 | gemena
# Processing Record 41 of Set 13 | guanica
# Processing Record 42 of Set 13 | point fortin
# Processing Record 43 of Set 13 | bagdarin
# Processing Record 44 of Set 13 | karimganj
# Processing Record 45 of Set 13 | mogadishu
# Processing Record 46 of Set 13 | batak
# Processing Record 47 of Set 13 | huarmey
# Processing Record 48 of Set 13 | huilong
# Processing Record 49 of Set 13 | nebug
# Processing Record 50 of Set 13 | sesheke
# Processing Record 1 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 14 | shangrao
# Processing Record 3 of Set 14 | jardim
# Processing Record 4 of Set 14 | araouane
# Processing Record 5 of Set 14 | lodja
# Processing Record 6 of Set 14 | port hedland
# Processing Record 7 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 14 | ntungamo
# Processing Record 9 of Set 14 | keelung
# Processing Record 10 of Set 14 | trinidad
# Processing Record 11 of Set 14 | san jose
# Processing Record 12 of Set 14 | san anselmo
# Processing Record 13 of Set 14 | nalut
# Processing Record 14 of Set 14 | zihuatanejo
# Processing Record 15 of Set 14 | gat
# Processing Record 16 of Set 14 | port augusta
# Processing Record 17 of Set 14 | aksha
# Processing Record 18 of Set 14 | takoradi
# Processing Record 19 of Set 14 | taywarah
# Processing Record 20 of Set 14 | comodoro rivadavia
# Processing Record 21 of Set 14 | pimenta bueno
# Processing Record 22 of Set 14 | saint anthony
# Processing Record 23 of Set 14 | qasigiannguit
# Processing Record 24 of Set 14 | sinnamary
# Processing Record 25 of Set 14 | arsk
# Processing Record 26 of Set 14 | can
# Processing Record 27 of Set 14 | san quintin
# Processing Record 28 of Set 14 | isiolo
# Processing Record 29 of Set 14 | sur
# Processing Record 30 of Set 14 | sisimiut
# Processing Record 31 of Set 14 | gatton
# Processing Record 32 of Set 14 | bowral
# Processing Record 33 of Set 14 | kupang
# Processing Record 34 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 35 of Set 14 | carauari
# Processing Record 36 of Set 14 | denpasar
# Processing Record 37 of Set 14 | zonguldak
# Processing Record 38 of Set 14 | olavarria
# Processing Record 39 of Set 14 | les cayes
# Processing Record 40 of Set 14 | alyangula
# Processing Record 41 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 14 | marand
# Processing Record 43 of Set 14 | acarau
# Processing Record 44 of Set 14 | biltine
# Processing Record 45 of Set 14 | polunochnoye
# Processing Record 46 of Set 14 | adwa
# Processing Record 47 of Set 14 | virginia beach
# Processing Record 48 of Set 14 | chapais
# Processing Record 49 of Set 14 | koumac
# Processing Record 50 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 15 | manicore
# Processing Record 2 of Set 15 | tahta
# Processing Record 3 of Set 15 | anadyr
# Processing Record 4 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 15 | lingao
# Processing Record 6 of Set 15 | bethanien
# Processing Record 7 of Set 15 | liverpool
# Processing Record 8 of Set 15 | mindelo
# Processing Record 9 of Set 15 | yulara
# Processing Record 10 of Set 15 | churapcha
# Processing Record 11 of Set 15 | politika
# Processing Record 12 of Set 15 | abu zabad
# Processing Record 13 of Set 15 | qafsah
# City not found. Skipping...
# Processing Record 14 of Set 15 | chenzhou
# Processing Record 15 of Set 15 | feijo
# Processing Record 16 of Set 15 | ritchie
# Processing Record 17 of Set 15 | parrita
# Processing Record 18 of Set 15 | malidong
# Processing Record 19 of Set 15 | jutai
# Processing Record 20 of Set 15 | berezovka
# Processing Record 21 of Set 15 | san borja
# Processing Record 22 of Set 15 | padang
# Processing Record 23 of Set 15 | wolomin
# Processing Record 24 of Set 15 | batagay
# Processing Record 25 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 26 of Set 15 | san carlos de bariloche
# Processing Record 27 of Set 15 | robertsport
# Processing Record 28 of Set 15 | strezhevoy
# Processing Record 29 of Set 15 | a
# City not found. Skipping...
# Processing Record 30 of Set 15 | sao jose dos campos
# Processing Record 31 of Set 15 | niono
# Processing Record 32 of Set 15 | nuevo progreso
# Processing Record 33 of Set 15 | arlit
# Processing Record 34 of Set 15 | ponta delgada
# Processing Record 35 of Set 15 | laiyang
# Processing Record 36 of Set 15 | abu samrah
# Processing Record 37 of Set 15 | obera
# Processing Record 38 of Set 15 | hofn
# Processing Record 39 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 40 of Set 15 | daru
# Processing Record 41 of Set 15 | bilma
# Processing Record 42 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 44 of Set 15 | wattegama
# Processing Record 45 of Set 15 | luena
# Processing Record 46 of Set 15 | auki
# Processing Record 47 of Set 15 | tsuruoka
# Processing Record 48 of Set 15 | bintulu
# Processing Record 49 of Set 15 | grand-lahou
# Processing Record 50 of Set 15 | qovlar
# Processing Record 1 of Set 16 | scottsbluff
# Processing Record 2 of Set 16 | shakawe
# Processing Record 3 of Set 16 | ottawa
# Processing Record 4 of Set 16 | rock sound
# Processing Record 5 of Set 16 | muzaffarabad
# Processing Record 6 of Set 16 | bonavista
# Processing Record 7 of Set 16 | saint-augustin
# Processing Record 8 of Set 16 | bouca
# Processing Record 9 of Set 16 | waipawa
# Processing Record 10 of Set 16 | krasnyy yar
# Processing Record 11 of Set 16 | ballitoville
# Processing Record 12 of Set 16 | curitibanos
# Processing Record 13 of Set 16 | namatanai
# Processing Record 14 of Set 16 | jiaozuo
# Processing Record 15 of Set 16 | vredendal
# Processing Record 16 of Set 16 | malinovoye ozero
# Processing Record 17 of Set 16 | sulmona
# Processing Record 18 of Set 16 | alexandria
# Processing Record 19 of Set 16 | khonuu
# City not found. Skipping...
# Processing Record 20 of Set 16 | inhambane
# Processing Record 21 of Set 16 | taylor
# Processing Record 22 of Set 16 | warmbad
# Processing Record 23 of Set 16 | maloy
# Processing Record 24 of Set 16 | kysyl-syr
# Processing Record 25 of Set 16 | terekli-mekteb
# Processing Record 26 of Set 16 | naze
# Processing Record 27 of Set 16 | santa fe
# Processing Record 28 of Set 16 | mesyagutovo
# Processing Record 29 of Set 16 | xai-xai
# Processing Record 30 of Set 16 | kijang
# Processing Record 31 of Set 16 | itaqui
# Processing Record 32 of Set 16 | roberval
# Processing Record 33 of Set 16 | shamkhal
# Processing Record 34 of Set 16 | whitianga
# Processing Record 35 of Set 16 | tombouctou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.

city_data_df = pd.DataFrame(city_data)


# Reorder columns

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Butaritari      KI   3.0707  172.7902     82.11        72          20
# 1      Berlevag      NO  70.8578   29.0864     62.60        67           0
# 2       Hualmay      PE -11.0964  -77.6139     61.27        84          71
# 3  Richards Bay      ZA -28.7830   32.0377     66.02        77          16
# 4        Barrow      US  71.2906 -156.7887     48.22        87         100
# 5     Upernavik      GL  72.7868  -56.1549     42.58        96         100
# 6        Hobart      AU -42.8794  147.3294     53.46        77          75
# 7      Katsuura      JP  35.1333  140.3000     77.40        76          98
# 8       Ushuaia      AR -54.8000  -68.3000     35.89        97          99
# 9    North Bend      US  43.4065 -124.2243     58.91        94           0
#
#    Wind Speed Current Description
# 0        9.62          few clouds
# 1        5.75           clear sky
# 2        6.85       broken clouds
# 3        5.82          few clouds
# 4       13.80          light rain
# 5       14.27          light rain
# 6        9.22          light rain
# 7       15.86     overcast clouds
# 8        1.25     overcast clouds
# 9        8.05           clear sky

# %%
# Create the output file (CSV).

output_data_file = "WeatherPy_Database.csv"


# Export the City_Data into a CSV.

city_data_df.to_csv(output_data_file, index_label="City_ID")
